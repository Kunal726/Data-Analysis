# %% [markdown]
# # Project Title - COVID 19 Data Analysis
#
# Covid 19 Data analysis. Covid-19 is the huge pandamic faced by the world from last 2 years. Due to this virus huge ammount of loss of life hat taken. Today we will analize the same data.
#
# The dataset has been downloaded from https://covid19.who.int/ Dataset. The libraries for data analysis and visualization used in this project are Numpy, Pandas, Matplotlib and Seaborn. These libraries are covered in the course by Jovian.ml named as Data Analysis with Python: Zero to Pandas.

# %%
project_name = 'Covid19-data-analysis'

# %%
import jovian

# %%
jovian.commit(project = project_name)
# Out:
# [jovian] Updating notebook "kulthekunal1/covid19-data-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/kulthekunal1/covid19-data-analysis
# 'https://jovian.ai/kulthekunal1/covid19-data-analysis'

# %% [markdown]
# ## Data Preparation and Cleaning

# %%
import pandas as pd

# %%
covid_ds = pd.read_csv('WHO COVID-19.csv')

# %%
# Displaying Data
covid_ds
# Out:
#      Sr_No                      Name       WHO Region  \
# 0        1  United States of America         Americas
# 1        2                     India  South-East Asia
# 2        3                    Brazil         Americas
# 3        4        Russian Federation           Europe
# 4        5                    France           Europe
# ..     ...                       ...              ...
# 232    233              Saint Helena           Africa
# 233    234                   Tokelau  Western Pacific
# 234    235                     Tonga  Western Pacific
# 235    236              Turkmenistan           Europe
# 236    237                    Tuvalu  Western Pacific
#
#      Cases - cumulative total  Cases - cumulative total per 100000 population  \
# 0                    35957692                                        10863.26
# 1                    32077706                                         2324.46
# 2                    20212642                                         9509.17
# ...

# %%
# In Short Description of Data
covid_ds.describe()
# Out:
#             Sr_No  Cases - cumulative total  \
# count  237.000000              2.370000e+02
# mean   119.000000              8.634804e+05
# std     68.560193              3.517522e+06
# min      1.000000              0.000000e+00
# 25%     60.000000              5.349000e+03
# 50%    119.000000              5.579000e+04
# 75%    178.000000              3.933020e+05
# max    237.000000              3.595769e+07
#
#        Cases - cumulative total per 100000 population  \
# count                                      236.000000
# mean                                      4051.496949
# std                                       4348.384310
# min                                          0.000000
# 25%                                        307.385000
# 50%                                       2498.560000
# 75%                                       7103.075000
# max                                      19272.630000
#
#        Cases - newly reported in last 7 days  \
# ...

# %%
# Info of covid data
covid_ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 13 columns):
#  #   Column                                                        Non-Null Count  Dtype
# ---  ------                                                        --------------  -----
#  0   Sr_No                                                         237 non-null    int64
#  1   Name                                                          237 non-null    object
#  2   WHO Region                                                    237 non-null    object
#  3   Cases - cumulative total                                      237 non-null    int64
#  4   Cases - cumulative total per 100000 population                236 non-null    float64
#  5   Cases - newly reported in last 7 days                         237 non-null    int64
#  6   Cases - newly reported in last 7 days per 100000 population   236 non-null    float64
# ...

# %%
covid_ds.columns
# Out:
# Index(['Sr_No', 'Name', 'WHO Region', 'Cases - cumulative total',
#        'Cases - cumulative total per 100000 population',
#        'Cases - newly reported in last 7 days',
#        'Cases - newly reported in last 7 days per 100000 population',
#        'Cases - newly reported in last 24 hours', 'Deaths - cumulative total',
#        'Deaths - cumulative total per 100000 population',
#        'Deaths - newly reported in last 7 days',
#        'Deaths - newly reported in last 7 days per 100000 population',
#        'Deaths - newly reported in last 24 hours'],
#       dtype='object')

# %%
covid_ds['WHO Region']
# Out:
# 0             Americas
# 1      South-East Asia
# 2             Americas
# 3               Europe
# 4               Europe
#             ...
# 232             Africa
# 233    Western Pacific
# 234    Western Pacific
# 235             Europe
# 236    Western Pacific
# Name: WHO Region, Length: 237, dtype: object

# %%
# Renaming columns
covid_ds.rename(columns = {'Name' : 'Country', 'WHO Region' : 'Region', 
                           'Cases - cumulative total' : 'Total cases', 
                           'Cases - cumulative total per 100000 population' : 'Total Cases per 100000', 
                           'Cases - newly reported in last 7 days' : 'Reported last7 days',   
                           'Cases - newly reported in last 7 days per 100000 population' : 'Reported last7 days per 100000', 
                           'Cases - newly reported in last 24 hours' : 'Reported last 24 hrs', 
                           'Deaths - cumulative total' : 
                           'Total Deaths','Deaths - cumulative total per 100000 population' : 'Total deaths per 100000',
                           'Deaths - newly reported in last 7 days' : 'Deaths Reported last 7 days',
                           'Deaths - newly reported in last 7 days per 100000 population' : 'Deaths last 7 days per 100000 ',
                           'Deaths - newly reported in last 24 hours' : 'Deaths Reported last 24 hrs' }, inplace = True)

# %%
covid_ds.columns
# Out:
# Index(['Sr_No', 'Country', 'Region', 'Total cases', 'Total Cases per 100000',
#        'Reported last7 days', 'Reported last7 days per 100000',
#        'Reported last 24 hrs', 'Total Deaths', 'Total deaths per 100000',
#        'Deaths Reported last 7 days', 'Deaths last 7 days per 100000 ',
#        'Deaths Reported last 24 hrs'],
#       dtype='object')

# %%
covid_ds
# Out:
#      Sr_No                   Country           Region  Total cases  \
# 0        1  United States of America         Americas     35957692
# 1        2                     India  South-East Asia     32077706
# 2        3                    Brazil         Americas     20212642
# 3        4        Russian Federation           Europe      6534791
# 4        5                    France           Europe      6216600
# ..     ...                       ...              ...          ...
# 232    233              Saint Helena           Africa            0
# 233    234                   Tokelau  Western Pacific            0
# 234    235                     Tonga  Western Pacific            0
# 235    236              Turkmenistan           Europe            0
# 236    237                    Tuvalu  Western Pacific            0
#
#      Total Cases per 100000  Reported last7 days  \
# 0                  10863.26               820038
# 1                   2324.46               265592
# ...

# %%
covid_ds.index
# Out:
# RangeIndex(start=0, stop=237, step=1)

# %%
covid_ds.drop(columns = ['Reported last7 days per 100000','Reported last7 days per 100000', 'Total deaths per 100000','Deaths last 7 days per 100000 '], inplace=True)

# %%
covid_ds.columns
# Out:
# Index(['Sr_No', 'Country', 'Region', 'Total cases', 'Total Cases per 100000',
#        'Reported last7 days', 'Reported last 24 hrs', 'Total Deaths',
#        'Deaths Reported last 7 days', 'Deaths Reported last 24 hrs'],
#       dtype='object')

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "kulthekunal1/covid19-data-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/kulthekunal1/covid19-data-analysis
# 'https://jovian.ai/kulthekunal1/covid19-data-analysis'

# %% [markdown]
# ## Exploratory analysis and visualization

# %%
# importing libraries
import matplotlib as mp
import matplotlib.pyplot as plt
import seaborn as sns

# %%
covid_ds.Country.count()
# Out:
# 237

# %%
# Unique Countries
covid_ds.Country.unique()
# Out:
# array(['United States of America', 'India', 'Brazil',
#        'Russian Federation', 'France', 'The United Kingdom', 'Turkey',
#        'Argentina', 'Colombia', 'Spain', 'Italy',
#        'Iran (Islamic Republic of)', 'Germany', 'Indonesia', 'Mexico',
#        'Poland', 'South Africa', 'Ukraine', 'Peru', 'Netherlands', 'Iraq',
#        'Philippines', 'Czechia', 'Chile', 'Canada', 'Bangladesh',
#        'Malaysia', 'Belgium', 'Sweden', 'Romania', 'Pakistan', 'Japan',
#        'Portugal', 'Israel', 'Thailand', 'Hungary', 'Jordan',
#        'Kazakhstan', 'Serbia', 'Switzerland', 'Nepal', 'Morocco',
#        'United Arab Emirates', 'Austria', 'Tunisia', 'Lebanon',
#        'Saudi Arabia', 'Greece', 'Ecuador', 'Cuba',
#        'Bolivia (Plurinational State of)', 'Georgia', 'Belarus',
#        'Paraguay', 'Panama', 'Bulgaria', 'Costa Rica', 'Kuwait',
#        'Guatemala', 'Slovakia', 'Uruguay', 'Croatia', 'Azerbaijan',
#        'occupied Palestinian territory, including east Jerusalem',
# ...

# %% [markdown]
# ## Number of cases with respect to region

# %%
no_cases_region = covid_ds.groupby('Region')[['Total cases']].sum()

no_cases_region = no_cases_region.sort_values('Region', ascending = False).reset_index()

no_cases_region.rename(columns = {'Total cases' : 'total_cases'}, inplace = True)

# %%
no_cases_region
# Out:
#                   Region  total_cases
# 0        Western Pacific      5128768
# 1        South-East Asia     39594191
# 2                  Other          764
# 3                 Europe     61931642
# 4  Eastern Mediterranean     13388957
# 5               Americas     79380211
# 6                 Africa      5220316

# %%
mp.rcParams['font.size'] = 14
mp.rcParams['figure.figsize'] = (15, 7.5)
mp.rcParams['figure.facecolor'] = '#00000000'
sns.set_style("darkgrid")

# %%
plt.title("Cases with respect to Region")
plt.xlabel('Regions')
plt.ylabel('Total cases')
plt.plot(no_cases_region.Region, no_cases_region.total_cases);

# %% [markdown]
# ## Number of Cases with respect to country

# %%
no_cases_country = covid_ds.groupby('Country')[['Total cases']].sum()

no_cases_country = no_cases_country.sort_values('Country', ascending = True).reset_index()

no_cases_country.rename(columns = {'Total cases' : 'total_cases'}, inplace = True)

# %%
plt.figure(figsize=(20, 85))
plt.title('Number of cases with respect to Country',fontweight=800)
sns.barplot(x='total_cases', y='Country', data=no_cases_country);

# %% [markdown]
# ## Total deaths with respect to country

# %%
covid_ds.columns
# Out:
# Index(['Sr_No', 'Country', 'Region', 'Total cases', 'Total Cases per 100000',
#        'Reported last7 days', 'Reported last 24 hrs', 'Total Deaths',
#        'Deaths Reported last 7 days', 'Deaths Reported last 24 hrs'],
#       dtype='object')

# %%
no_deaths_country = covid_ds.groupby('Country')[['Total Deaths']].sum()

no_deaths_country = no_deaths_country.sort_values('Country', ascending = True).reset_index()

no_deaths_country.rename(columns = {'Total Deaths' : 'total_deaths'}, inplace = True)

# %%
no_deaths_country
# Out:
#                                                Country  total_deaths
# 0                                          Afghanistan          6988
# 1                                              Albania          2460
# 2                                              Algeria          4654
# 3                                       American Samoa             0
# 4                                              Andorra           129
# ..                                                 ...           ...
# 232                                  Wallis and Futuna             7
# 233                                              Yemen          1392
# 234                                             Zambia          3509
# 235                                           Zimbabwe          3991
# 236  occupied Palestinian territory, including east...          3886
#
# [237 rows x 2 columns]

# %%
plt.figure(figsize=(20, 85))
plt.title('Number of deaths with respect to Country',fontweight=800)
sns.barplot(x='total_deaths', y='Country', data=no_deaths_country);

# %% [markdown]
# ## Total deaths with respect to Region

# %%
no_deaths_region = covid_ds.groupby('Region')[['Total Deaths']].sum()

no_deaths_region = no_deaths_region.sort_values('Region', ascending = True).reset_index()

no_deaths_region.rename(columns = {'Total Deaths' : 'total_deaths'}, inplace = True)

no_deaths_region

plt.figure(figsize=(35, 15))
plt.title('Number of deaths with respect to Country',fontweight=800)
sns.barplot(y='total_deaths', x='Region', data=no_deaths_region);

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "kulthekunal1/covid19-data-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/kulthekunal1/covid19-data-analysis
# 'https://jovian.ai/kulthekunal1/covid19-data-analysis'

# %% [markdown]
# # Questions

# %% [markdown]
# In this section the following questions will be asked:
# 1. How many cases are there in India in last 7 days?
# 2. Total cases in Argentina?
# 3. How many cases are there in India in total per Million?
# 4. Total cases in Africa Region?
# 5. Which region has highest number of cases?

# %% [markdown]
# # How many cases are there in India in last 7 days?

# %%
cases_india = covid_ds[covid_ds.Country == 'India']

# %%
cases_last_7_days = cases_india['Reported last7 days']

# %%
print("Total cases in India in last 7 Days are {}".format(cases_last_7_days[1]))
# Out:
# Total cases in India in last 7 Days are 265592

# %% [markdown]
# # Total cases in Argentina?

# %%
cases_Argentina = covid_ds[covid_ds.Country == 'Argentina']

# %%
cases_total = cases_Argentina['Total cases'].sum()

# %%
print("Total cases in Argentina are {}".format(cases_total))
# Out:
# Total cases in Argentina are 5041487

# %% [markdown]
# # How many cases are there in India in total per Million?

# %%
cases_india_m = covid_ds[covid_ds.Country == 'India']
cases_per_m = cases_india_m['Total Cases per 100000'].sum()
print("Total cases in India per Million are {} million".format(cases_per_m))
# Out:
# Total cases in India per Million are 2324.46 million

# %% [markdown]
# # Total cases in Africa Region?

# %%
cases_africa = covid_ds[covid_ds.Region == 'Africa']
cases_africa = cases_africa['Total cases'].sum()
print("Total cases in Africa region are {} ".format(cases_africa))
# Out:
# Total cases in Africa region are 5220316

# %% [markdown]
# # Which region has highest number of cases?

# %%
cases_region = covid_ds.groupby('Region')[['Total cases']].sum()
cases_region.sort_values('Total cases', ascending=False)
# Out:
#                        Total cases
# Region
# Americas                  79380211
# Europe                    61931642
# South-East Asia           39594191
# Eastern Mediterranean     13388957
# Africa                     5220316
# Western Pacific            5128768
# Other                          764

# %%
print('Region with highest Number of cases is Americas')
# Out:
# Region with highest Number of cases is Americas

# %%
jovian.commit()
# Out:
# [jovian] Updating notebook "kulthekunal1/covid19-data-analysis" on https://jovian.ai/
# [jovian] Committed successfully! https://jovian.ai/kulthekunal1/covid19-data-analysis
# 'https://jovian.ai/kulthekunal1/covid19-data-analysis'

# %% [markdown]
# ## Section-4: Conclusion
#
# The above analysis on WHO COVID-19.csv can be summarised as below:
#
#
# 1.Dataset contains 237 Countries.
#
#
# 2.Dataset contains 7 regions.
#
#
# 3.Dataset contains recognized cases and death cases.
#
#
# 4.Dataset Contains death rates per 7 days.

# %%
jovian.submit(assignment="zero-to-pandas-project")
